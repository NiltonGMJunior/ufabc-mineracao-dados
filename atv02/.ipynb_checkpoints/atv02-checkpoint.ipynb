# %%
import pandas as pd

# %%
df_auto = pd.read_csv("./auto-data.csv")

# %%
df_auto.head()
# Out:
#          MAKE FUELTYPE ASPIRE DOORS       BODY DRIVE CYLINDERS  HP   RPM  \
# 0      subaru      gas    std   two  hatchback   fwd      four  69  4900
# 1   chevrolet      gas    std   two  hatchback   fwd     three  48  5100
# 2       mazda      gas    std   two  hatchback   fwd      four  68  5000
# 3      toyota      gas    std   two  hatchback   fwd      four  62  4800
# 4  mitsubishi      gas    std   two  hatchback   fwd      four  68  5500
#
#    MPG-CITY  MPG-HWY  PRICE
# 0        31       36   5118
# 1        47       53   5151
# 2        30       31   5195
# 3        35       39   5348
# 4        37       41   5389

# %%
df_auto.corr()
# Out:
#                 HP       RPM  MPG-CITY   MPG-HWY     PRICE
# HP        1.000000  0.103574 -0.821960 -0.803658  0.811953
# RPM       0.103574  1.000000 -0.107648 -0.050632 -0.101319
# MPG-CITY -0.821960 -0.107648  1.000000  0.972407 -0.692948
# MPG-HWY  -0.803658 -0.050632  0.972407  1.000000 -0.708659
# PRICE     0.811953 -0.101319 -0.692948 -0.708659  1.000000

# %%
df_auto.groupby(["DOORS", "FUELTYPE"]).count()
# Out:
#                 MAKE  ASPIRE  BODY  DRIVE  CYLINDERS  HP  RPM  MPG-CITY  \
# DOORS FUELTYPE
# four  diesel      16      16    16     16         16  16   16        16
#       gas         96      96    96     96         96  96   96        96
# two   diesel       3       3     3      3          3   3    3         3
#       gas         82      82    82     82         82  82   82        82
#
#                 MPG-HWY  PRICE
# DOORS FUELTYPE
# four  diesel         16     16
#       gas            96     96
# two   diesel          3      3
#       gas            82     82

# %%
df_auto.groupby("BODY").mean()["PRICE"]
# Out:
# BODY
# convertible    21890.500000
# hardtop        22208.500000
# hatchback       9958.373134
# sedan          14563.739130
# wagon          12500.166667
# Name: PRICE, dtype: float64

# %%
df_auto.groupby("DRIVE").mean()["MPG-CITY"]
# Out:
# DRIVE
# 4wd    24.000000
# fwd    28.210526
# rwd    20.626667
# Name: MPG-CITY, dtype: float64

# %%
df_auto.sort_values("MPG-CITY")
# Out:
#               MAKE FUELTYPE ASPIRE DOORS       BODY DRIVE CYLINDERS   HP  \
# 191         jaguar      gas    std   two      sedan   rwd    twelve  262
# 196  mercedes-benz      gas    std   two    hardtop   rwd     eight  184
# 194  mercedes-benz      gas    std  four      sedan   rwd     eight  184
# 192            bmw      gas    std  four      sedan   rwd       six  182
# 190         jaguar      gas    std  four      sedan   rwd       six  176
# ..             ...      ...    ...   ...        ...   ...       ...  ...
# 48          toyota      gas    std  four      sedan   fwd      four   70
# 13       chevrolet      gas    std   two  hatchback   fwd      four   70
# 33          nissan   diesel    std   two      sedan   fwd      four   55
# 1        chevrolet      gas    std   two  hatchback   fwd     three   48
# 16           honda      gas    std   two  hatchback   fwd      four   58
#
#       RPM  MPG-CITY  MPG-HWY  PRICE
# 191  5000        13       17  36000
# ...
